# %%
import torch

from PIL import Image
from Main import Main
from transformers import CLIPTokenizer
from Pipeline import Pipeline

# %%
ENABLE_CUDA = False
ENABLE_MPS = False 

device = 'cpu'
if torch.cuda.is_available() and ENABLE_CUDA:
    device = 'cuda'
elif (torch.backends.mps.is_available() or torch.has_mps) and ENABLE_MPS:
    device = 'mps'

print(f'using device: {device}')

tokenizer = CLIPTokenizer('../data/tokenizer_vocab.json', '../data/tokenizer_merges.txt')
main = Main()
models = main.preload_models_from_std_weights('../data/v1-5-pruned-emaonly.ckpt', device)

# text-to-image
prompt = "A cat stretching on the floor, highly detailed, ultra sharp, cinematic, 8k resolution"
uncond_prompt = ""
do_cfg = True
cfg_scale = 7.5

# image-to-image
image = None
strength = 0.9
# image = Image('')

sampler = 'ddpm'
inference_steps = 50
seed = 42

output_img = Pipeline().generate(prompt,
                                 uncond_prompt,
                                 image,
                                 strength,
                                 do_cfg,
                                 cfg_scale,
                                 sampler,
                                 inference_steps,
                                 models,
                                 seed,
                                 device,
                                 'cpu',
                                 tokenizer)

Image.fromarray(output_img)
# Out:
# using device: cpu
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 18
#      16 tokenizer = CLIPTokenizer('../data/tokenizer_vocab.json', '../data/tokenizer_merges.txt')
#      17 main = Main()
# ---> 18 models = main.preload_models_from_std_weights('../data/v1-5-pruned-emaonly.ckpt', device)
#      20 # text-to-image
#      21 prompt = "A cat stretching on the floor, highly detailed, ultra sharp, cinematic, 8k resolution"
#
# File ~/machine-learning/deep_learning/implement_nn/stable_diffusion/src/Main.py:16, in Main.preload_models_from_std_weights(self, path, device)
#      13 def preload_models_from_std_weights(self, path, device):
#      14     state_dict = model_converter.load_from_std_weights(path, device)
# ---> 16     encoder = VAEEncoder().to(device)
#      17     # print('ENCODER DICT:', encoder.state_dict().keys())
#      18     encoder.load_state_dict(state_dict['encoder'], strict=True)
#
# File ~/machine-learning/deep_learning/implement_nn/stable_diffusion/src/VAE/VAEEncoder.py:32, in VAEEncoder.__init__(self)
#      12 def __init__(self):
#      13     super().__init__(
#      14         # in: (B, 3, H, W) -> out: (B, 8, H/8, W/8)
#      15         nn.Conv2d(Config.IMG_CH, Config.IN_CH, kernel_size=3, padding=1),
#      16         ResidualBlock(Config.IN_CH, Config.IN_CH),
#      17         ResidualBlock(Config.IN_CH, Config.IN_CH),
#      18
#      19         nn.Conv2d(Config.IN_CH, Config.IN_CH, kernel_size=3, stride=2, padding=0),
#      20         ResidualBlock(Config.IN_CH, 2*Config.IN_CH),
#      21         ResidualBlock(2*Config.IN_CH, 2*Config.IN_CH),
#      22
#      23         nn.Conv2d(2*Config.IN_CH, 2*Config.IN_CH, kernel_size=3, stride=2, padding=0),
#      24         ResidualBlock(2*Config.IN_CH, 4*Config.IN_CH),
#      25         ResidualBlock(4*Config.IN_CH, 4*Config.IN_CH),
#      26
#      27         nn.Conv2d(4*Config.IN_CH, 4*Config.IN_CH, kernel_size=3, stride=2, padding=0),
#      28         ResidualBlock(4*Config.IN_CH, 4*Config.IN_CH),
#      29         ResidualBlock(4*Config.IN_CH, 4*Config.IN_CH),
#      30         ResidualBlock(4*Config.IN_CH, 4*Config.IN_CH),
#      31
# ---> 32         AttentionBlock(4*Config.IN_CH),
#      33         ResidualBlock(4*Config.IN_CH, 4*Config.IN_CH),
#      34
#      35         nn.GroupNorm(32, 4*Config.IN_CH),
#      36         nn.SiLU(),
#      37
#      38         nn.Conv2d(4*Config.IN_CH, Config.OUT_CH, kernel_size=3, padding=1),
#      39         nn.Conv2d(Config.OUT_CH, Config.OUT_CH, kernel_size=1, padding=0)
#      40     )
#
# File ~/machine-learning/deep_learning/implement_nn/stable_diffusion/src/attention/AttentionBlock.py:15, in AttentionBlock.__init__(self, features)
#      13 super().__init__()
#      14 self.group_norm = nn.GroupNorm(32, features)
# ---> 15 self.attention = SelfAttention(1, features)
#
# TypeError: 'module' object is not callable
